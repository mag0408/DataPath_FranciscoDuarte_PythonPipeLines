# %%
import mysql.connector as connection 
import pandas as pd
import mysql
from io import StringIO
import seaborn as sns


mydb = mysql.connector.connect(
    host="34.16.84.34",
    user="root",
    passwd="123Qaz456$$D8",
    database="classicmodels"
)

query = "select p.productName, p.buyPrice, p.productVendor, n.textDescription from classicmodels.products p  inner join classicmodels.productlines n on p.productLine = n.productLine;"

df = pd.read_sql(query,mydb)

mydb.close()

df.head()

filtered_df = df[df['buyPrice'] > 100]
print(filtered_df.head())


filtered_df = df[df['productVendor'] == 'Second Gear Diecast']
print(filtered_df.head())

sns.histplot(data=df, x='buyPrice', bins=20, kde=True)
# Out:
# C:\Users\fout\AppData\Local\Temp\ipykernel_9408\1589338062.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,mydb)
#                        productName  buyPrice         productVendor  \
# 2           1962 LanciaA Delta 16V    103.42   Second Gear Diecast
# 14  1998 Chrysler Plymouth Prowler    101.51  Gearbox Collectibles
#
#                                       textDescription
# 2   Attention car enthusiasts: Make your wildest c...
# 14  Attention car enthusiasts: Make your wildest c...
#                   productName  buyPrice        productVendor  \
# 2      1962 LanciaA Delta 16V    103.42  Second Gear Diecast
# 4           2001 Ferrari Enzo     95.59  Second Gear Diecast
# 7            1969 Ford Falcon     83.05  Second Gear Diecast
# 30    1982 Lamborghini Diablo     16.24  Second Gear Diecast
# ...
